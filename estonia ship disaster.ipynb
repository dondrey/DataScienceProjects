# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('C:\\Users\\oluda\\Study Centre\\Data Science\\Dataset\\estonia-passenger-list.csv')

# %%
df
# Out:
#      PassengerId  Country             Firstname  Lastname Sex  Age Category  \
# 0              1   Sweden           ARVID KALLE     AADLI   M   62        P
# 1              2  Estonia                   LEA   AALISTE   F   22        C
# 2              3  Estonia                  AIRI   AAVASTE   F   21        C
# 3              4   Sweden                  JURI     AAVIK   M   53        C
# 4              5   Sweden       BRITTA ELISABET  AHLSTROM   F   55        P
# ..           ...      ...                   ...       ...  ..  ...      ...
# 984          985   Sweden  ANNA INGRID BIRGITTA    OSTROM   F   60        P
# 985          986   Sweden          ELMAR MIKAEL       OUN   M   34        P
# 986          987   Sweden                   ENN   QUNAPUU   M   77        P
# 987          988   Sweden                    LY   GUNAPUU   F   87        P
# 988          989   Sweden                  CARL    OVBERG   M   42        P
#
#      Survived
# 0           0
# 1           0
# ...

# %%
report = ProfileReport(df, title='Estonia Data Analysis', explorative=True)

# %%
report.to_widgets()

# %%
len(df[df.Survived == 0])
# Out:
# 852

# %%
dead_age = df[df.Survived == 0]

# %%
df.describe()
# Out:
#        PassengerId         Age    Survived
# count   989.000000  989.000000  989.000000
# mean    494.992922   44.575329    0.138524
# std     285.643660   17.235146    0.345624
# min       1.000000    0.000000    0.000000
# 25%     248.000000   30.000000    0.000000
# 50%     495.000000   44.000000    0.000000
# 75%     742.000000   59.000000    0.000000
# max     989.000000   87.000000    1.000000

# %%
dead_age
# Out:
#      PassengerId  Country             Firstname   Lastname Sex  Age Category  \
# 0              1   Sweden           ARVID KALLE      AADLI   M   62        P
# 1              2  Estonia                   LEA    AALISTE   F   22        C
# 2              3  Estonia                  AIRI    AAVASTE   F   21        C
# 3              4   Sweden                  JURI      AAVIK   M   53        C
# 4              5   Sweden       BRITTA ELISABET   AHLSTROM   F   55        P
# ..           ...      ...                   ...        ...  ..  ...      ...
# 982          983   Sweden           MAUD HELENA  QSTERVALL   F   24        P
# 983          984   Sweden          GUNNEL MARIE    OSTLUND   F   51        P
# 984          985   Sweden  ANNA INGRID BIRGITTA     OSTROM   F   60        P
# 986          987   Sweden                   ENN    QUNAPUU   M   77        P
# 987          988   Sweden                    LY    GUNAPUU   F   87        P
#
#      Survived
# 0           0
# ...

# %%
dead_age.Age.value_counts()
# Out:
# 49    24
# 67    24
# 45    23
# 30    21
# 50    20
#       ..
# 87     1
# 6      1
# 9      1
# 81     1
# 0      1
# Name: Age, Length: 76, dtype: int64

# %%
989-852
# Out:
# 137

# %%
survived_age = df[df.Survived == 1]

# %%
survived_age
# Out:
#      PassengerId  Country      Firstname   Lastname Sex  Age Category  \
# 21            22  Estonia           PAUL   ANDERSON   M   32        C
# 31            32   Sweden     PER ALBERT  ANDERSSON   M   50        P
# 37            38   Latvia       NIKOLAJS  ANDREJEVS   M   36        P
# 44            45  Estonia           ANTI       ARAK   M   21        P
# 48            49  Estonia          JANNO       ASER   M   21        P
# ..           ...      ...            ...        ...  ..  ...      ...
# 958          959   Sweden  YASMINA SOFIA  WEIDINGER   F   18        P
# 965          966  Germany      SIEGFRIED       WOLF   M   38        P
# 981          982   Sweden   LARS TORSTEN  OSTERBERG   M   48        P
# 985          986   Sweden   ELMAR MIKAEL        OUN   M   34        P
# 988          989   Sweden           CARL     OVBERG   M   42        P
#
#      Survived
# 21          1
# 31          1
# 37          1
# 44          1
# 48          1
# ..        ...
# 958         1
# ...

# %%
dead_age.describe()
# Out:
#        PassengerId         Age  Survived
# count   852.000000  852.000000     852.0
# mean    490.800469   46.273474       0.0
# std     284.656178   17.332352       0.0
# min       1.000000    0.000000       0.0
# 25%     242.500000   32.000000       0.0
# 50%     496.500000   46.500000       0.0
# 75%     732.250000   61.000000       0.0
# max     988.000000   87.000000       0.0

# %%
df_dead_age = dead_age.groupby(["Age"]).count()["PassengerId"].reset_index(name="Count")
df_dead_age.head(100)
# Out:
#     Age  Count
# 0     0      1
# 1     2      1
# 2     4      1
# 3     5      2
# 4     6      1
# ..  ...    ...
# 71   78      4
# 72   80      2
# 73   81      1
# 74   82      2
# 75   87      1
#
# [76 rows x 2 columns]

# %%
import pandas

# %%
df.describe()
# Out:
#        PassengerId         Age    Survived
# count   989.000000  989.000000  989.000000
# mean    494.992922   44.575329    0.138524
# std     285.643660   17.235146    0.345624
# min       1.000000    0.000000    0.000000
# 25%     248.000000   30.000000    0.000000
# 50%     495.000000   44.000000    0.000000
# 75%     742.000000   59.000000    0.000000
# max     989.000000   87.000000    1.000000

# %%
bins = [0, 30, 44, 59, 87]
label = ["0-29", "30-43", "44-58", "59-87"]
df["Age_Band"] = pd.cut(df.Age, bins, labels=label, include_lowest=True)

# %%
df
# Out:
#      PassengerId  Country             Firstname  Lastname Sex  Age Category  \
# 0              1   Sweden           ARVID KALLE     AADLI   M   62        P
# 1              2  Estonia                   LEA   AALISTE   F   22        C
# 2              3  Estonia                  AIRI   AAVASTE   F   21        C
# 3              4   Sweden                  JURI     AAVIK   M   53        C
# 4              5   Sweden       BRITTA ELISABET  AHLSTROM   F   55        P
# ..           ...      ...                   ...       ...  ..  ...      ...
# 984          985   Sweden  ANNA INGRID BIRGITTA    OSTROM   F   60        P
# 985          986   Sweden          ELMAR MIKAEL       OUN   M   34        P
# 986          987   Sweden                   ENN   QUNAPUU   M   77        P
# 987          988   Sweden                    LY   GUNAPUU   F   87        P
# 988          989   Sweden                  CARL    OVBERG   M   42        P
#
#      Survived Age_Band
# 0           0    59-87
# ...

# %%
plt.figure(figsize=(15,7))
estonia=sns.countplot(x="Age_Band", hue="Survived", data=df)
plt.title("Rate of Death/Survival in Respect to Age")
estonia.set(xlabel="Age Band", ylabel="Number of Dead/Survival")
#plt.savefig("C:/Users/oluda/Downloads/dataViz.jpg")
# Out:
# [Text(0, 0.5, 'Number of Dead/Survival'), Text(0.5, 0, 'Age Band')]

# %%
pandas.set_option('display.max_rows', 20)
print(df)
# Out:
#      PassengerId  Country             Firstname  Lastname Sex  Age Category  \
# 0              1   Sweden           ARVID KALLE     AADLI   M   62        P
# 1              2  Estonia                   LEA   AALISTE   F   22        C
# 2              3  Estonia                  AIRI   AAVASTE   F   21        C
# 3              4   Sweden                  JURI     AAVIK   M   53        C
# 4              5   Sweden       BRITTA ELISABET  AHLSTROM   F   55        P
# ..           ...      ...                   ...       ...  ..  ...      ...
# 984          985   Sweden  ANNA INGRID BIRGITTA    OSTROM   F   60        P
# 985          986   Sweden          ELMAR MIKAEL       OUN   M   34        P
# 986          987   Sweden                   ENN   QUNAPUU   M   77        P
# 987          988   Sweden                    LY   GUNAPUU   F   87        P
# 988          989   Sweden                  CARL    OVBERG   M   42        P
#
#      Survived Age_Band
# 0           0    59-87
# ...

# %%
df
# Out:
#      PassengerId  Country             Firstname  Lastname Sex  Age Category  \
# 0              1   Sweden           ARVID KALLE     AADLI   M   62        P
# 1              2  Estonia                   LEA   AALISTE   F   22        C
# 2              3  Estonia                  AIRI   AAVASTE   F   21        C
# 3              4   Sweden                  JURI     AAVIK   M   53        C
# 4              5   Sweden       BRITTA ELISABET  AHLSTROM   F   55        P
# ..           ...      ...                   ...       ...  ..  ...      ...
# 984          985   Sweden  ANNA INGRID BIRGITTA    OSTROM   F   60        P
# 985          986   Sweden          ELMAR MIKAEL       OUN   M   34        P
# 986          987   Sweden                   ENN   QUNAPUU   M   77        P
# 987          988   Sweden                    LY   GUNAPUU   F   87        P
# 988          989   Sweden                  CARL    OVBERG   M   42        P
#
#      Survived Age_Band
# 0           0    59-87
# ...

# %%
plt.figure(figsize=(15,7))
estonia=sns.countplot(x="Category", hue="Survived", data=df)
plt.title("The Rate of Death and Survival in Respect to Crew or Passenger")
estonia.set(xlabel="Passenger/Crew", ylabel="Number of Dead/Survival")
#plt.savefig("C:/Users/oluda/Downloads/dataViz.jpg")
# Out:
# [Text(0, 0.5, 'Number of Dead/Survival'), Text(0.5, 0, 'Passenger/Crew')]

# %%
df.Category.value_counts()
# Out:
# P    796
# C    193
# Name: Category, dtype: int64

# %%
796+193
# Out:
# 989

# %%
df.sort_values("Category", ascending=False)
# Out:
#      PassengerId  Country          Firstname    Lastname Sex  Age Category  \
# 0              1   Sweden        ARVID KALLE       AADLI   M   62        P
# 600          601   Sweden  KARIN MARIE VIOLA     NILSSON   F   28        P
# 602          603   Sweden           KARL OVE     NILSSON   M   44        P
# 603          604   Sweden         MONA IRENE     NILSSON   F   58        P
# 604          605   Sweden        OVE LENNART     NILSSON   M   57        P
# ..           ...      ...                ...         ...  ..  ...      ...
# 524          525  Estonia              TERJE        LOUK   F   27        C
# 842          843   Sweden           HANS UNO    SVENSSON   M   40        C
# 349          350  Estonia             PEETER  KANNUSSAAR   M   30        C
# 350          351  Estonia              SIRJE      KANTER   F   37        C
# 694          695   Sweden            SUSANNE       PUNDI   F   33        C
#
#      Survived Age_Band
# 0           0    59-87
# ...

# %%
df.sort_values("Category")
# Out:
#      PassengerId  Country       Firstname  Lastname Sex  Age Category  \
# 752          753  Estonia      RIINA-MALL      RAST   F   36        C
# 715          716  Estonia            ILMI    RAIDMA   F   38        C
# 718          719  Estonia           HELVE    RANDMA   F   44        C
# 721          722  Estonia          KULDAR  RAUDMANN   M   26        C
# 723          724  Estonia       LJUDMILLA  RAUDSEPP   F   47        C
# ..           ...      ...             ...       ...  ..  ...      ...
# 348          349   Sweden   ULLA BIRGITTA  KANDEMAN   F   55        P
# 351          352   Sweden  GARTIE TERESIA  KARLBERG   F   64        P
# 352          353   Sweden    ANDERS HAKAN  KARLSSON   M   38        P
# 319          320  Estonia             LIA     JURME   F   63        P
# 988          989   Sweden            CARL    OVBERG   M   42        P
#
#      Survived Age_Band
# 752         0    30-43
# 715         0    30-43
# 718         0    30-43
# 721         0     0-29
# ...

# %%
plt.figure(figsize=(15,7))
estonia=sns.countplot(x="Sex", hue="Survived", data=df)
plt.title("The Rate of Death and Survival in Respect to Sex")
estonia.set(xlabel="Passenger/Crew Sex", ylabel="Number of Dead/Survival")
plt.show()
#plt.savefig("C:/Users/oluda/Downloads/dataViz.jpg")

# %%
df.Sex.value_counts()
# Out:
# M    503
# F    486
# Name: Sex, dtype: int64

# %%
countt=df.groupby(["Sex", "Survived"])["PassengerId"].count().reset_index(name="Count")

# %%
countt
# Out:
#   Sex  Survived  Count
# 0   F         0    459
# 1   F         1     27
# 2   M         0    393
# 3   M         1    110

# %%
import matplotlib.pyplot as plt

x=[1,2,3]
y=[9,8,7]

plt.plot(x,y)
for a,b in zip(x, y): 
    plt.text(a, b, str(b))
plt.show()

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

snsdf = sns.load_dataset("tips")
groupedvalues=snsdf.groupby('day').sum().reset_index()

pal = sns.color_palette("Greens_d", len(groupedvalues))
rank = groupedvalues["total_bill"].argsort().argsort() 
g=sns.barplot(x='day',y='tip',data=groupedvalues, palette=np.array(pal[::-1])[rank])

for index, row in groupedvalues.iterrows():
    g.text(row.name,row.tip, round(row.total_bill,2), color='black', ha="center")

plt.show()

# %%
groupedvalues
# Out:
#     day  total_bill     tip  size
# 0  Thur     1096.33  171.83   152
# 1   Fri      325.88   51.96    40
# 2   Sat     1778.40  260.40   219
# 3   Sun     1627.16  247.39   216
