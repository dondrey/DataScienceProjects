# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/oluda/Study Centre/Data Science/Dataset/noshowappointments/KaggleV2-May-2016.csv")
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110526 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110526 non-null  float64
#  1   AppointmentID   110526 non-null  int64
#  2   Gender          110526 non-null  object
#  3   ScheduledDay    110526 non-null  datetime64[ns]
#  4   AppointmentDay  110526 non-null  datetime64[ns]
#  5   Age             110526 non-null  int64
#  6   Neighbourhood   110526 non-null  object
#  7   Scholarship     110526 non-null  int64
#  8   Hipertension    110526 non-null  int64
#  9   Diabetes        110526 non-null  int64
#  10  Alcoholism      110526 non-null  int64
#  11  Handcap         110526 non-null  int64
#  12  SMS_received    110526 non-null  int64
#  13  No-show         110526 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(8), object(3)
# memory usage: 12.6+ MB

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105210e+05   1.105210e+05  110521.000000  110521.000000
# mean   1.474906e+14   5.675304e+06      37.089386       0.098271
# std    2.560860e+14   7.129691e+04      23.109885       0.297682
# min    3.921784e+04   5.030230e+06       0.000000       0.000000
# 25%    4.172457e+12   5.640284e+06      18.000000       0.000000
# 50%    3.173185e+13   5.680573e+06      37.000000       0.000000
# 75%    9.438963e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110521.000000  110521.000000  110521.000000  110521.000000
# mean        0.197257       0.071869       0.030401       0.022231
# std         0.397929       0.258272       0.171690       0.161494
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df["No-show"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df[df.Age < 0]
# Out:
# Empty DataFrame
# Columns: [PatientId, AppointmentID, Gender, ScheduledDay, AppointmentDay, Age, Neighbourhood, Scholarship, Hipertension, Diabetes, Alcoholism, Handcap, SMS_received, No-show]
# Index: []

# %%
df.query("Age >= 0", inplace=True)

# %%
df['ScheduledDay'] = df['ScheduledDay'].astype('datetime64[ns]')
df['AppointmentDay'] = df['AppointmentDay'].astype('datetime64[ns]')

# %%
df["ScheduledDay"] = pd.to_datetime(df.ScheduledDay)

# %%
df['AppointmentDay'] = pd.to_datetime(df.AppointmentDay)

# %%
df.Gender.value_counts()
# Out:
# F    71839
# M    38687
# Name: Gender, dtype: int64

# %%
df.SMS_received.value_counts()
# Out:
# 0    75044
# 1    35482
# Name: SMS_received, dtype: int64

# %%
df['DOTW_Scheduled'] = df['ScheduledDay'].dt.day_name()

# %%
df['DOTW_Appointment'] = df['AppointmentDay'].dt.day_name()

# %%
df.head(50)
# Out:
#        PatientId  AppointmentID Gender        ScheduledDay AppointmentDay  \
# 0   2.987250e+13        5642903      F 2016-04-29 18:38:08     2016-04-29
# 1   5.589978e+14        5642503      M 2016-04-29 16:08:27     2016-04-29
# 2   4.262962e+12        5642549      F 2016-04-29 16:19:04     2016-04-29
# 3   8.679512e+11        5642828      F 2016-04-29 17:29:31     2016-04-29
# 4   8.841186e+12        5642494      F 2016-04-29 16:07:23     2016-04-29
# 5   9.598513e+13        5626772      F 2016-04-27 08:36:51     2016-04-29
# 6   7.336882e+14        5630279      F 2016-04-27 15:05:12     2016-04-29
# 7   3.449833e+12        5630575      F 2016-04-27 15:39:58     2016-04-29
# 8   5.639473e+13        5638447      F 2016-04-29 08:02:16     2016-04-29
# 9   7.812456e+13        5629123      F 2016-04-27 12:48:25     2016-04-29
# 10  7.345362e+14        5630213      F 2016-04-27 14:58:11     2016-04-29
# 11  7.542951e+12        5620163      M 2016-04-26 08:44:12     2016-04-29
# ...

# %%
df["Date_Difference"] = (df.AppointmentDay - df.ScheduledDay).astype("timedelta64[D]")

# %%
df[df.Date_Difference < 0]
# Out:
#            PatientId  AppointmentID Gender        ScheduledDay AppointmentDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08     2016-04-29
# 1       5.589978e+14        5642503      M 2016-04-29 16:08:27     2016-04-29
# 2       4.262962e+12        5642549      F 2016-04-29 16:19:04     2016-04-29
# 3       8.679512e+11        5642828      F 2016-04-29 17:29:31     2016-04-29
# 4       8.841186e+12        5642494      F 2016-04-29 16:07:23     2016-04-29
# ...              ...            ...    ...                 ...            ...
# 110511  8.235996e+11        5786742      F 2016-06-08 08:50:20     2016-06-08
# 110512  9.876246e+13        5786368      F 2016-06-08 08:20:01     2016-06-08
# 110513  8.674778e+13        5785964      M 2016-06-08 07:52:55     2016-06-08
# 110514  2.695685e+12        5786567      F 2016-06-08 08:35:31     2016-06-08
# 110517  5.574942e+12        5780122      F 2016-06-07 07:38:34     2016-06-07
#
# ...

# %%
df.query("Date_Difference >= -1", inplace=True)

# %%
ageIndex = df[df["Age"] == -1].index
df.drop(ageIndex, inplace=True)
# Out:
# F    71839
# M    38687
# Name: Gender, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# F    71836
# M    38685
# Name: Gender, dtype: int64

# %%
71836 + 38685
# Out:
# 110521

# %%
df["Date_Difference"].replace({-1.0: 0}, inplace=True)

# %%
d_f=df

# %%
d_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110521 entries, 0 to 110526
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   PatientId         110521 non-null  float64
#  1   AppointmentID     110521 non-null  int64
#  2   Gender            110521 non-null  object
#  3   ScheduledDay      110521 non-null  datetime64[ns]
#  4   AppointmentDay    110521 non-null  datetime64[ns]
#  5   Age               110521 non-null  int64
#  6   Neighbourhood     110521 non-null  object
#  7   Scholarship       110521 non-null  int64
#  8   Hipertension      110521 non-null  int64
#  9   Diabetes          110521 non-null  int64
#  10  Alcoholism        110521 non-null  int64
#  11  Handcap           110521 non-null  int64
#  12  SMS_received      110521 non-null  int64
#  13  No-show           110521 non-null  object
#  14  DOTW_Scheduled    110521 non-null  object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110521 entries, 0 to 110526
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   PatientId         110521 non-null  float64
#  1   AppointmentID     110521 non-null  int64
#  2   Gender            110521 non-null  object
#  3   ScheduledDay      110521 non-null  datetime64[ns]
#  4   AppointmentDay    110521 non-null  datetime64[ns]
#  5   Age               110521 non-null  int64
#  6   Neighbourhood     110521 non-null  object
#  7   Scholarship       110521 non-null  int64
#  8   Hipertension      110521 non-null  int64
#  9   Diabetes          110521 non-null  int64
#  10  Alcoholism        110521 non-null  int64
#  11  Handcap           110521 non-null  int64
#  12  SMS_received      110521 non-null  int64
#  13  No-show           110521 non-null  object
#  14  DOTW_Scheduled    110521 non-null  object
# ...

# %%
plt.figure(figsize=(15,7))
df.plot("Age", "Date_Difference", kind="scatter")
plt.title("Scatter Plot")
# Out:
# Text(0.5, 1.0, 'Scatter Plot')

# %%
df.groupby(["DOTW_Appointment", "Gender", "No-show"]).count()["PatientId"]
#.reset_index(name="NS_Count")
# Out:
# DOTW_Appointment  Gender  No-show
# Monday            F       No         11575.0
#                           Yes         3101.0
#                   M       No          6449.0
#                           Yes         1588.0
# Tuesday           F       No         13452.0
#                           Yes         3421.0
#                   M       No          7036.0
#                           Yes         1729.0
# Wednesday         F       No         13565.0
#                           Yes         3298.0
#                   M       No          7209.0
#                           Yes         1794.0
# Thursday          F       No          8965.0
#                           Yes         2152.0
#                   M       No          4944.0
#                           Yes         1185.0
# Friday            F       No          9666.0
#                           Yes         2612.0
#                   M       No          5316.0
#                           Yes         1425.0
# ...

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# %%
days
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
df["DOTW_Appointment"] = pd.Categorical(df.DOTW_Appointment, categories=days, ordered=True)

# %%
df["DOTW_Scheduled"] = pd.Categorical(df.DOTW_Scheduled, categories=days, ordered=True)

# %%
df_heatmap = NS_Count.pivot(index="DOTW_Appointment", columns="No-show", values="NS_Count")
plt.figure(figsize=(12,7))
sns.heatmap(df_heatmap)
plt.title('HeatMap Showing Relationship Between Number of Appointments and WeekDays')
# Out:
# Text(0.5, 1, 'HeatMap Showing Relationship Between Number of Appointments and WeekDays')

# %%
df.groupby(["DOTW_Appointment", "No-show"]).count()["PatientId"]
# Out:
# DOTW_Appointment  No-show
# Monday            No         18024.0
#                   Yes         4689.0
# Tuesday           No         20488.0
#                   Yes         5150.0
# Wednesday         No         20774.0
#                   Yes         5092.0
# Thursday          No         13909.0
#                   Yes         3337.0
# Friday            No         14982.0
#                   Yes         4037.0
# Saturday          No            30.0
#                   Yes            9.0
# Sunday            No             NaN
#                   Yes            NaN
# Name: PatientId, dtype: float64

# %%
NS_Count = df.groupby(["DOTW_Appointment", "No-show"])["PatientId"].count().reset_index(name="NS_Count")

# %%
NS_Count
# Out:
#    DOTW_Appointment No-show  NS_Count
# 0            Monday      No     18024
# 1            Monday     Yes      4689
# 2           Tuesday      No     20488
# 3           Tuesday     Yes      5150
# 4         Wednesday      No     20774
# 5         Wednesday     Yes      5092
# 6          Thursday      No     13909
# 7          Thursday     Yes      3337
# 8            Friday      No     14982
# 9            Friday     Yes      4037
# 10         Saturday      No        30
# 11         Saturday     Yes         9
# 12           Sunday      No         0
# 13           Sunday     Yes         0

# %%
weekdayhour = cons2016.groupby(["Weekday", "Hour"]).mean()
weekdayhour = weekdayhour.reset_index()
weekdayhour.head()

# %%
dfmean = df.groupby(["DOTW_Appointment", "No-show"]).mean()

dfmean.head()
# Out:
#                              PatientId  AppointmentID        Age  Scholarship  \
# DOTW_Appointment No-show
# Monday           No       1.487300e+14   5.677861e+06  37.466545     0.093486
#                  Yes      1.491772e+14   5.645532e+06  34.371081     0.114097
# Tuesday          No       1.486443e+14   5.686967e+06  37.847813     0.094787
#                  Yes      1.456888e+14   5.658922e+06  34.927767     0.120194
# Wednesday        No       1.463925e+14   5.691564e+06  37.872052     0.093867
#
#                           Hipertension  Diabetes  Alcoholism   Handcap  \
# DOTW_Appointment No-show
# Monday           No           0.199567  0.068964    0.030182  0.021249
#                  Yes          0.169119  0.069951    0.034122  0.020047
# Tuesday          No           0.207390  0.077118    0.028016  0.022843
#                  Yes          0.171262  0.057282    0.031845  0.022718
# Wednesday        No           0.201935  0.072591    0.031482  0.021084
#
# ...

# %%
dfmean
# Out:
#                              PatientId  AppointmentID        Age  Scholarship  \
# DOTW_Appointment No-show
# Monday           No       1.487300e+14   5.677861e+06  37.466545     0.093486
#                  Yes      1.491772e+14   5.645532e+06  34.371081     0.114097
# Tuesday          No       1.486443e+14   5.686967e+06  37.847813     0.094787
#                  Yes      1.456888e+14   5.658922e+06  34.927767     0.120194
# Wednesday        No       1.463925e+14   5.691564e+06  37.872052     0.093867
#                  Yes      1.464699e+14   5.663283e+06  33.699921     0.115279
# Thursday         No       1.434183e+14   5.676906e+06  37.837443     0.094256
#                  Yes      1.511670e+14   5.648613e+06  34.737788     0.103986
# Friday           No       1.509556e+14   5.666567e+06  37.914364     0.092911
#                  Yes      1.421654e+14   5.640588e+06  33.864503     0.121377
# Saturday         No       9.259928e+13   5.681159e+06  53.200000     0.100000
# ...

# %%
df["PatientId"].count()
# Out:
# 110521

# %%
plt.figure(figsize=(15,7))
dataViz=sns.countplot(x="DOTW_Appointment", hue="No-show", data=df)
plt.title("Relationship Between Weekdays and Appointment")
dataViz.set(xlabel="Week Days", ylabel="Number of Appointments")
#plt.savefig("C:/Users/oluda/Downloads/dataViz.jpg")
# Out:
# [Text(0, 0.5, 'Number of Appointments'), Text(0.5, 0, 'Week Days')]

# %%
plt.figure(figsize=(15,7))
dataViz = sns.countplot(x="DOTW_Appointment", hue="No-show", data=df)
dataViz.set_title("Relationship Between Weekdays and Appointment")
# Out:
# Text(0.5, 1.0, 'Relationship Between Weekdays and Appointment')

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105210e+05   1.105210e+05  110521.000000  110521.000000
# mean   1.474906e+14   5.675304e+06      37.089386       0.098271
# std    2.560860e+14   7.129691e+04      23.109885       0.297682
# min    3.921784e+04   5.030230e+06       0.000000       0.000000
# 25%    4.172457e+12   5.640284e+06      18.000000       0.000000
# 50%    3.173185e+13   5.680573e+06      37.000000       0.000000
# 75%    9.438963e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110521.000000  110521.000000  110521.000000  110521.000000
# mean        0.197257       0.071869       0.030401       0.022231
# std         0.397929       0.258272       0.171690       0.161494
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
bins = [0, 18, 37, 55, 115]
label = ["0-17", "18-36", "37-54", "55-155"]
df["Age_Band"] = pd.cut(df.Age, bins, labels=label, include_lowest=True)

# %%
df[["Age_Band", "Age"]]
# Out:
#        Age_Band  Age
# 0        55-155   62
# 1        55-155   56
# 2        55-155   62
# 3          0-17    8
# 4        55-155   56
# ...         ...  ...
# 110522   55-155   56
# 110523    37-54   51
# 110524    18-36   21
# 110525    37-54   38
# 110526    37-54   54
#
# [110521 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110521 entries, 0 to 110526
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   PatientId         110521 non-null  float64
#  1   AppointmentID     110521 non-null  int64
#  2   Gender            110521 non-null  object
#  3   ScheduledDay      110521 non-null  datetime64[ns]
#  4   AppointmentDay    110521 non-null  datetime64[ns]
#  5   Age               110521 non-null  int64
#  6   Neighbourhood     110521 non-null  object
#  7   Scholarship       110521 non-null  int64
#  8   Hipertension      110521 non-null  int64
#  9   Diabetes          110521 non-null  int64
#  10  Alcoholism        110521 non-null  int64
#  11  Handcap           110521 non-null  int64
#  12  SMS_received      110521 non-null  int64
#  13  No-show           110521 non-null  object
#  14  DOTW_Scheduled    110521 non-null  category
# ...

# %%
df.Age_Band.value_counts()
# Out:
# (-0.001, 18.0]    28865
# (55.0, 115.0]     27503
# (18.0, 37.0]      27248
# (37.0, 55.0]      26905
# Name: Age_Band, dtype: int64

# %%
df.groupby(["Age_Band", "No-show"]).count()["PatientId"].reset_index(name="Number_of_Patients")
# Out:
#   Age_Band No-show  Number_of_Patients
# 0     0-17      No               22519
# 1     0-17     Yes                6346
# 2    18-36      No               20836
# 3    18-36     Yes                6412
# 4    37-54      No               21651
# 5    37-54     Yes                5254
# 6   55-155      No               23201
# 7   55-155     Yes                4302

# %%
df.groupby(["Age_Band", "No-show"]).count()["PatientId"]
# Out:
# Age_Band  No-show
# 0-17      No         22519
#           Yes         6346
# 18-36     No         20836
#           Yes         6412
# 37-54     No         21651
#           Yes         5254
# 55-155    No         23201
#           Yes         4302
# Name: PatientId, dtype: int64

# %%
plt.figure(figsize=(15,7))
dataViz=sns.countplot(x="Age_Band", hue="No-show", data=df)
dataViz.set(xlabel="Age Band", ylabel="Number of Appointments")
plt.title("The Relationship Between Age and Appointment")
# Out:
# Text(0.5, 1.0, 'The Relationship Between Age and Appointment')

# %%
df.groupby(["Gender", "No-show"]).count()["PatientId"]
# Out:
# Gender  No-show
# F       No         57245
#         Yes        14591
# M       No         30962
#         Yes         7723
# Name: PatientId, dtype: int64

# %%
plt.figure(figsize=(15,7))
dataViz=sns.countplot(x="Gender", hue="No-show", data=df)
#dataViz.set(xlabel="Age Band", ylabel="Number of Appointments")
plt.title("The Relationship Between Gender and Showing-up for Appointment")
# Out:
# Text(0.5, 1.0, 'The Relationship Between Gender and Showing-up for Appointment')

# %%
dfGender=df.groupby(["DOTW_Appointment", "Gender", "No-show"]).count()["PatientId"].reset_index(name="NS_Count")
dfGender
# Out:
#    DOTW_Appointment Gender No-show  NS_Count
# 0            Monday      F      No   11575.0
# 1            Monday      F     Yes    3101.0
# 2            Monday      M      No    6449.0
# 3            Monday      M     Yes    1588.0
# 4           Tuesday      F      No   13452.0
# 5           Tuesday      F     Yes    3421.0
# 6           Tuesday      M      No    7036.0
# 7           Tuesday      M     Yes    1729.0
# 8         Wednesday      F      No   13565.0
# 9         Wednesday      F     Yes    3298.0
# 10        Wednesday      M      No    7209.0
# 11        Wednesday      M     Yes    1794.0
# 12         Thursday      F      No    8965.0
# 13         Thursday      F     Yes    2152.0
# 14         Thursday      M      No    4944.0
# 15         Thursday      M     Yes    1185.0
# 16           Friday      F      No    9666.0
# 17           Friday      F     Yes    2612.0
# 18           Friday      M      No    5316.0
# 19           Friday      M     Yes    1425.0
# ...

# %%
plt.figure(figsize=(17,9))
#dataViz=sns.countplot(x="Gender", hue="No-show", data=df)
sns.countplot(x="DOTW_Appointment", hue="Gender",  data=df)
#dataViz.set(xlabel="Age Band", ylabel="Number of Appointments")
plt.title("The Number of Male and Female Appointments Expected per Week Day")
# Out:
# Text(0.5, 1.0, 'The Number of Male and Female Appointments Expected per Week Day')

# %%
plt.figure(figsize=(15,10))
#dataViz=sns.countplot(x="Gender", hue="No-show", data=df)
sns.countplot(x="DOTW_Appointment", hue="No-show",  data=df)
#dataViz.set(xlabel="Age Band", ylabel="Number of Appointments")
plt.title("The Relationship Between People Showing-up and not Showing-up for Appointment")
# Out:
# Text(0.5, 1.0, 'The Relationship Between People Showing-up and not Showing-up for Appointment')

# %%
df.groupby(["Date_Difference", "No-show"]).count()["PatientId"].reset_index()
# Out:
#      Date_Difference No-show  PatientId
# 0                0.0      No      40870
# 1                0.0     Yes       2905
# 2                1.0      No       5123
# 3                1.0     Yes       1602
# 4                2.0      No       2093
# ..               ...     ...        ...
# 228            168.0     Yes          1
# 229            175.0      No         10
# 230            175.0     Yes          6
# 231            178.0      No          8
# 232            178.0     Yes          2
#
# [233 rows x 3 columns]

# %%
bins = [0, 3, 14, 178]
label = ["0-2", "3-13", "14-178"]
df["Date_Difference_Band"] = pd.cut(df.Date_Difference, bins, labels=label, include_lowest=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110521 entries, 0 to 110526
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   PatientId             110521 non-null  float64
#  1   AppointmentID         110521 non-null  int64
#  2   Gender                110521 non-null  object
#  3   ScheduledDay          110521 non-null  datetime64[ns]
#  4   AppointmentDay        110521 non-null  datetime64[ns]
#  5   Age                   110521 non-null  int64
#  6   Neighbourhood         110521 non-null  object
#  7   Scholarship           110521 non-null  int64
#  8   Hipertension          110521 non-null  int64
#  9   Diabetes              110521 non-null  int64
#  10  Alcoholism            110521 non-null  int64
#  11  Handcap               110521 non-null  int64
#  12  SMS_received          110521 non-null  int64
#  13  No-show               110521 non-null  object
# ...

# %%
plt.figure(figsize=(15,7))
dataViz=sns.countplot(x="Date_Difference_Band", hue="No-show", data=df)
#dataViz.set(xlabel="Age Band", ylabel="Number of Appointments")
plt.title("The Relationship Between Date_Difference_Band and Showing-up for Appointment")
# Out:
# Text(0.5, 1.0, 'The Relationship Between Date_Difference_Band and Showing-up for Appointment')
